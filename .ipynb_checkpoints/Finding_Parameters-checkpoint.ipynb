# %%
import numpy as np
# %matplotlib inline
from matplotlib import pyplot as plt
from scipy.optimize import minimize
from scipy.optimize import curve_fit
import pandas as pd

# %%
# data_100 = './test_data/20191120_Kinetics_CV_100rpm_C02.txt'
# data_400 = './test_data/20191120_Kinetics_CV_400rpm_C02.txt'
# data_900 = './test_data/20191120_Kinetics_CV_900rpm_C02.txt'
# data_1600 = './test_data/20191120_Kinetics_CV_1600rpm_C02.txt'
# data_2500 = './test_data/20191120_Kinetics_CV_2500rpm_C02.txt'

# %%
# rpm100 = pd.read_csv(data_100,sep='\t',header=(0),usecols=range(12)) 
# rpm400 = pd.read_csv(data_400,sep='\t',header=(0),usecols=range(12)) 
# rpm900 = pd.read_csv(data_900,sep='\t',header=(0),usecols=range(12)) 
# rpm1600 = pd.read_csv(data_1600,sep='\t',header=(0),usecols=range(12)) 
# rpm2500 = pd.read_csv(data_2500,sep='\t',header=(0),usecols=range(12))

# %%
data_100 = './RDE_data/02262020_MnO2_RDE_50mVs_100rpm_ExtendedBounds_IncreasedFlow_C04.mpt'
data_400 = './RDE_data/02262020_MnO2_RDE_50mVs_400rpm_ExtendedBounds_IncreasedFlow_C04.mpt'
data_900 = './RDE_data/02262020_MnO2_RDE_50mVs_900rpm_ExtendedBounds_IncreasedFlow_C04.mpt'
data_1600 = './RDE_data/02262020_MnO2_RDE_50mVs_1600rpm_ExtendedBounds_IncreasedFlow_C04.mpt'
data_2500 = './RDE_data/02262020_MnO2_RDE_50mVs_2500rpm_ExtendedBounds_IncreasedFlow_C04.mpt'

# %%
rpm100 = pd.read_csv(data_100,sep='\t',header=(52),usecols=range(12)) 
rpm400 = pd.read_csv(data_400,sep='\t',header=(52),usecols=range(12)) 
rpm900 = pd.read_csv(data_900,sep='\t',header=(52),usecols=range(12)) 
rpm1600 = pd.read_csv(data_1600,sep='\t',header=(52),usecols=range(12)) 
rpm2500 = pd.read_csv(data_2500,sep='\t',header=(52),usecols=range(12))

# %%
RPM = rpm100,rpm400,rpm900,rpm1600,rpm2500

# %%
rpm400
# Out:
#        mode  ox/red  error  control changes  counter inc.      time/s  \
# 0         2       1      0                0             0    0.000000
# 1         2       1      0                0             0    0.011000
# 2         2       1      0                0             0    0.031000
# 3         2       1      0                0             0    0.051000
# 4         2       1      0                0             0    0.071000
# ...     ...     ...    ...              ...           ...         ...
# 25565     2       1      0                1             0  511.881987
# 25566     2       1      0                1             0  511.901987
# 25567     2       1      0                1             0  511.921987
# 25568     2       1      0                1             0  511.936987
# 25569     2       1      0                0             0  511.941987
#
#        control/V     Ewe/V    <I>/mA  cycle number  (Q-Qo)/C       P/W
# 0      -0.996980 -0.997440 -0.264734           1.0  0.000000  0.000264
# 1      -0.996430 -0.996845 -0.249511           1.0 -0.000003  0.000249
# 2      -0.995430 -0.995866 -0.226134           1.0 -0.000008  0.000225
# 3      -0.994429 -0.994879 -0.207541           1.0 -0.000012  0.000206
# 4      -0.993429 -0.993882 -0.192264           1.0 -0.000016  0.000191
# ...          ...       ...       ...           ...       ...       ...
# 25565  -1.003033 -1.003505 -0.049891           4.0 -0.019142  0.000050
# 25566  -1.002033 -1.002477 -0.049846           4.0 -0.019143  0.000050
# 25567  -1.001032 -1.001485 -0.049786           4.0 -0.019144  0.000050
# 25568  -1.000282 -1.000743 -0.049698           4.0 -0.019145  0.000050
# 25569  -0.999982 -1.000361 -0.049619           4.0 -0.019145  0.000050
#
# [25570 rows x 12 columns]

# %%
plt.plot(rpm100['time/s'],rpm100['P/W'])
plt.ylabel('Power [W]')
plt.xlabel('time [s]')
plt.show()

plt.plot(rpm100['time/s'],rpm100['<I>/mA'])
plt.ylabel('Current [mA]')
plt.xlabel('time [s]')
plt.show()

plt.plot(rpm100['time/s'],rpm100['Ewe/V'])
plt.ylabel('Voltage')
plt.xlabel('time [s]')
plt.show()

# %%
# # This is from test data when current was not included and we had to calculate it!
# P_100 = np.array(rpm100['P/W'])
# Ewe_100 = np.array(rpm100['Ewe/V'])
# I_100 = P_100/Ewe_100*1000 
# cycles_100 = rpm100['cycle number']

# plt.plot(rpm100['time/s'],I_100)
# plt.ylabel('Current [mA]')
# plt.xlabel('time [s]')
# plt.show()

# %%
P_100 = np.array(rpm100['P/W'])
Ewe_100 = np.array(rpm100['Ewe/V'])
I_100 = np.array(rpm100['<I>/mA'])
cycles_100 = rpm100['cycle number']

plt.plot(rpm100['time/s'],I_100)
plt.ylabel('Current [mA]')
plt.xlabel('time [s]')
plt.show()

# %%
#Looking for equilibrium voltage

ocvs = []

print('{:9s} {:17s} {:14s}'.format('time[s]','current [mA]','V'))
for l in range(len(I_100)):
    if abs(I_100[l]) < 1e-5:
        print('{:5.1f} {:12.1e} {:12.3f}'.format(rpm100['time/s'][l],rpm100['<I>/mA'][l],rpm100['Ewe/V'][l]))
        value = rpm100['Ewe/V'][l] 
        if value > 0:
            ocvs.append(value)
            
equil_potential = np.average(ocvs)
equil_potential
# Out:
# time[s]   current [mA]      V
#  12.6     -2.3e-07       -0.366
#  56.7     -4.0e-06        0.561
#  56.7     -7.8e-06        0.560
# 138.0      8.5e-06       -0.495
# 185.1      5.7e-07        0.543
# 313.1     -1.4e-06        0.544
# 394.1     -1.7e-06       -0.490
# 441.0      9.7e-06        0.548
# 441.0      6.2e-06        0.547
# 0.5506727116666666

# %% [raw]
# threshold = .5e-3
# voltage_of_interest = 0.3 #V
# currents_pt3 = np.zeros(4)
# #print the first occurrence of the
# print('index  time(s)  voltage  current(A)')
# for item in range(len(Ewe_100)):
#     for n in range(1,5):
#         if abs(Ewe_100[item] - voltage_of_interest) < threshold and cycles_100[item] == n and I_100[item] > 1e-3:
#             print(n)
#             print(f"{item:}   {rpm100['time/s'][item]:5.2f}  {Ewe_100[item]:8.4f}  {I_100[item]:10.2e}")
#             currents_pt3[n-1] = I_100[item]
#
# avg_current_pt3 = np.average(currents_pt3)/1000
# avg_current_pt3

# %% [raw]
# def find_current_voltage_pair(voltage_of_interest)

# %%
# m = 0
# Es = []
# Is = []
# while cycles_100[m] == 1:
#     Es.append(Ewe_100[m])
#     Is.append(I_100[m])
    
plt.plot(Ewe_100,I_100)

# %%
E_cycle1 = []
E_cycle2 = []
E_cycle3 = []
E_cycle4 = []

i_cycle1 = []
i_cycle2 = []
i_cycle3 = []
i_cycle4 = []

for m in range(len(cycles_100)):
    if cycles_100[m] == 1:
        E_cycle1.append(Ewe_100[m])
        i_cycle1.append(I_100[m])
    elif cycles_100[m] == 2:
        E_cycle2.append(Ewe_100[m])
        i_cycle2.append(I_100[m])
    elif cycles_100[m] == 3:
        E_cycle3.append(Ewe_100[m])
        i_cycle3.append(I_100[m])
    elif cycles_100[m] == 4:
        E_cycle4.append(Ewe_100[m])
        i_cycle4.append(I_100[m])

print(len(E_cycle1), len(E_cycle2), len(E_cycle3), len(E_cycle4))
print('cycles are different lengths- be aware when trying to compare')
# Out:
# 6388 6391 6391 6392
# cycles are different lengths- be aware when trying to compare

# %%
np.e
# Out:
# 2.718281828459045

# %%
overpotentials = np.array(E_cycle3) - 0.5507
overpotentials

fig, ax = plt.subplots()
ax.set_xscale('log', basex=np.e)
plt.plot(abs(np.array(i_cycle3)),overpotentials)
plt.ylabel('overpotential')
# plt.xscale('log')
# Out:
# Text(0, 0.5, 'overpotential')

# %% [raw]
# a = int(len(E_cycle3)/3)
# a = int(a*1.03)
# print(a, len(E_cycle3))
# b = int(len(E_cycle3)-a)
#
# plt.plot(E_cycle3[0:a],i_cycle3[0:a])
# # plt.plot(E_cycle3[b:],i_cycle3[b:])
# plt.plot(E_cycle3[int(a*2.5):],i_cycle3[int(a*2.5):])
# plt.xlabel('Voltage (V)')
# plt.ylabel('Current (mA)')
# plt.title('test')
# plt.show()
#
# plt.plot(E_cycle3[0:a],i_cycle3[0:a])
# plt.xlabel('Voltage (V)')
# plt.ylabel('Current (mA)')
# plt.title('first third')
# plt.show()
#
# plt.plot(E_cycle3[a:a*2],i_cycle3[a:a*2])
# plt.xlabel('Voltage (V)')
# plt.ylabel('Current (mA)')
# plt.title('second third')
# plt.show()
#
# plt.plot(E_cycle3[a:],i_cycle3[a:])
# plt.xlabel('Voltage (V)')
# plt.ylabel('Current (mA)')
# plt.title('final 2 thirds')
# plt.show()
#
# plt.plot(E_cycle3[a:int(a*2.3)],i_cycle3[a:int(a*2.3)])
# plt.xlabel('Voltage (V)')
# plt.ylabel('Current (mA)')
# plt.title('total down cycle')
# plt.show()
#
# plt.plot(E_cycle3,i_cycle3)
# plt.xlabel('Voltage (V)')
# plt.ylabel('Current (mA)')
# plt.title('full cycle 3')
# plt.show()

# %%
plt.plot(i_cycle3,np.array(E_cycle3)-.5507)
plt.ylabel('overpotential')
plt.xlabel('Current (mA)')
plt.title('full cycle 3')
plt.vlines(0,-2,1.5)
plt.show()

# %%
good_v = []
good_i = []
#-0.6065
for i in range(len(E_cycle3)):
    if E_cycle3[i]<1.2 and E_cycle3[i]>-0.6:
        good_v.append(E_cycle3[i])
        good_i.append(i_cycle3[i])

h = int(len(good_i)/2)
plt.plot(good_i[0:h],good_v[0:h])
plt.plot(good_i[h:],good_v[h:], label = 'use this')
plt.ylabel('Voltage [V]')
plt.xlabel('current [mA]')
plt.legend()
use_v = good_v[h:]
use_i = good_i[h:]

use_i[0], use_i[-1]

np.argmin(abs(np.array(use_i)))
use_i[655],use_v[655]
# Out:
# (-1.357671192951197e-06, 0.54415447)

# %%
# plt.plot(np.array(use_v),use_current_densities)
# plt.plot(use_v,np.zeros_like(use_v))
# plt.xlabel('Voltage (V)')
# plt.ylabel('Current density (mA/m^2)')
# plt.show()
def BV(E_cell, j0, aa, ac):
    F = 96485.33212 #C/mol
    R = 8.314 #J/mol-K
    T = 293 #K
#     equil_voltage = 0.5507 #V
    equil_voltage = 0.54415447 #V
#     equil_voltage = 0.3 #V
    overpotential = E_cell - equil_voltage
    z = 2
    
    j = j0*(np.exp(aa*z*F*overpotential*(R*T)**(-1))-np.exp(-ac*z*F*overpotential*(R*T)**(-1)))
    
    return j
val = .23
fitted_i = BV(np.array(use_v),.0113262,1-val,val)
# fitted_i = BV(np.array(use_v),0.0000002,.6,.4)
fitted_i
use_v
plt.plot(np.array(use_v),use_current_densities,'--r')
# plt.plot(use_v,np.zeros_like(use_v))
plt.plot(np.array(use_v),fitted_i)
# plt.xlim(left=0.46)
# plt.xlim(right=0.62)
plt.xlim(left=-.67)
plt.xlim(right=1.3)
# plt.ylim(-0.03,0.03)
plt.ylim(-4000,4000)
# BV(-0.5,.2,.5,.5)
# Out:
# (-4000, 4000)

# %% [markdown]
# ### Testing with 1 cycle:

# %%
test_E = E_cycle3[int(a*2.5):] + E_cycle3[0:a]
test_i = i_cycle3[int(a*2.5):] + i_cycle3[0:a]
# # plt.plot(E_cycle3[b:],i_cycle3[b:])
# plt.plot(E_cycle3[int(a*2.5):],i_cycle3[int(a*2.5):])
len(test_E), len(test_i)
plt.plot(test_E,test_i)
plt.title('total up cycle')
plt.show()
curve_fit?

# %%
test_v = []
test_i = []
for i in range(len(E_cycle3)):
    if E_cycle3[i] > -0.7 and E_cycle3[i] < 0.7:
        test_v.append(E_cycle3[i])
        test_i.append(i_cycle3[i])

# %%
half = int(len(test_v)/2)
plt.plot(test_v[half:],test_i[half:])
# Out:
# 0.001419738087760278

# %%
use_i[0],use_i[-1]
# Out:
# (0.0311067970469594, -0.005548086443013741)

# %%
diam_mm = 3 #mm 
D = diam_mm/1000
A = np.pi*D**2/4 #m^2

# %%
length = 20
use_current_densities = np.array(use_i)/A #mA/m^2
print(max(use_current_densities))
j0_guesses = np.linspace(min(use_current_densities),max(use_current_densities),length)
aa0_guesses = np.linspace(0.001,.87,len(j0_guesses))
ac0_guesses = np.linspace(0.003,.9,len(j0_guesses))

# p0s = np.zeros((length**3,3))
# for i in range(len(j0_guesses)):
#     p0s[0] = j0_guesses[]
    
    
p0s = np.array(np.meshgrid(j0_guesses,aa0_guesses,ac0_guesses)).T.reshape(-1,3)

np.shape(p0s)
# p0s
# Out:
# 4400.71156780441
# (8000, 3)

# %%
# curve_fit(objective_function, E_cycle1[0:a],i_cycle1[0:a])[0]
# a = int(len(E_cycle1)/2)
# a = int(len(E_cycle3)/3)
# a = int(a*1.03)
# ans = curve_fit(BV, E_cycle3[0:a],i_cycle3[0:a])

# print(use_current_densities)

# ans = curve_fit(BV,use_v,use_current_densities,[.5,.5,.5],bounds=([-np.inf,0,0],[np.inf,2,2]),maxfev=4000)
ans = curve_fit(BV,use_v,use_current_densities,[.5,.5,.5],maxfev=4000)

# ans = curve_fit(BV, test_E,test_i)
# ans = curve_fit(BV, np.array(E_cycle3[a:int(2.3*a)]),i_cycle3[a:int(2.3*a)])
j0_fit, aa_fit, ac_fit = ans[0]
print('j0,aa,ac:', j0_fit, aa_fit, ac_fit)
pcov = ans[1]
perr = np.sqrt(np.diag(pcov))
print('errors:',perr)
print('errors r this % of values:',perr/ans[0]*100 )
# Out:
# j0,aa,ac: 1.1876241852934167e-14 0.5250445056881325 0.49999999437602793
# errors: [2.47771381e-14 2.94212332e+04 2.32839183e-02]
# errors r this % of values: [2.08627766e+02 5.60356939e+06 4.65678372e+00]

# %%
options = np.zeros(len(p0s))
identified_js = []
identified_aas = []
identified_acs = []
for m in range(len(p0s)):
    try: 
        anss = curve_fit(BV,use_v,use_current_densities,p0s[m])
        gs = anss[0] 
#         if gs[1]>0 and gs[2]>0 and gs[1]-p0s[m,1]>1e-3 and gs[2]-p0s[m,2]>1e-3 and gs[0]>1e-2 and gs[0]-p0s[m,0]>1e-2: 
#             print('guess:',p0s[m],'\ngenerated:',anss[0],'\nerrors:',np.sqrt(np.diag(ans[1])),'\n')
        if gs[1]>0 and gs[2]>0 and abs(gs[1]-p0s[m,1])>1e-3 and abs(gs[2]-p0s[m,2])>1e-3 and gs[0]>1e-2 and abs(gs[0]-p0s[m,0])>1e-2: 
            print('guess:',p0s[m],'\ngenerated:',anss[0],'\nerrors:',np.sqrt(np.diag(anss[1])),'\n')
            identified_js.append(gs[0])
            identified_aas.append(gs[1])
            print(gs[1])
            identified_acs.append(gs[2])
            print(gs[2])
    except RuntimeError:
        print('runtime error\n')
# Out:
# guess: [-4.30989846e+03  4.67368421e-02  3.00000000e-03]
# generated: [5.27221461e+01 8.16569634e-02 4.85197566e-02]
# errors: [1.01053610e+00 4.17878661e-04 2.37337930e-04]
#
# 0.0816569633688382
# 0.048519756558201135
# guess: [-4.30989846e+03  9.24736842e-02  3.00000000e-03]
# generated: [5.27213203e+01 8.16573028e-02 4.85199511e-02]
# errors: [1.01044367e+00 4.17888165e-04 2.37343333e-04]
#
# 0.08165730278773928
# 0.048519951080036636
# guess: [-4.30989846e+03  1.38210526e-01  3.00000000e-03]
# generated: [5.27213308e+01 8.16572985e-02 4.85199486e-02]
# errors: [1.01044486e+00 4.17888039e-04 2.37343264e-04]
#
# 0.08165729847830203
# 0.0485199486089701
# guess: [-4.30989846e+03  1.83947368e-01  3.00000000e-03]
# generated: [5.27220417e+01 8.16570063e-02 4.85197811e-02]
# errors: [1.01052446e+00 4.17880014e-04 2.37338711e-04]
#
# 0.08165700628463367
# 0.0485197811329562
# guess: [-4.30989846e+03  2.29684211e-01  3.00000000e-03]
# generated: [5.27215497e+01 8.16572085e-02 4.85198971e-02]
# errors: [1.01046934e+00 4.17885504e-04 2.37341820e-04]
#
# 0.08165720851910489
# 0.048519897053088096
# guess: [-4.30989846e+03  2.75421053e-01  3.00000000e-03]
# generated: [5.27221079e+01 8.16569790e-02 4.85197655e-02]
# errors: [1.01053182e+00 4.17879132e-04 2.37338201e-04]
#
# 0.08165697904244135
# 0.04851976553858455
# guess: [-4.30989846e+03  3.21157895e-01  3.00000000e-03]
# generated: [5.27221263e+01 8.16569715e-02 4.85197612e-02]
# errors: [1.01053388e+00 4.17878928e-04 2.37338089e-04]
#
# 0.08165697150289733
# 0.0485197612166574
# guess: [-3.85144530e+03  4.67368421e-02  3.00000000e-03]
# generated: [5.27221903e+01 8.16569452e-02 4.85197461e-02]
# errors: [1.01054105e+00 4.17878155e-04 2.37337646e-04]
#
# 0.08165694515560983
# 0.048519746120925335
# guess: [-3.85144530e+03  9.24736842e-02  3.00000000e-03]
# generated: [5.
# runtime error
#
# runtime error
#
# runtime error
#
# runtime error
#
# runtime error
#
# runtime error
#
# runtime error
#
# runtime error
#
# guess: [4.40071157e+03 7.32789474e-01 9.00000000e-01]
# generated: [0.0113262  0.17690932 0.89324913]
# errors: [4.30381221e-02 2.96824490e+27 4.22030555e-02]
#
# 0.17690932423188374
# 0.8932491321171051

# %%
identified_js = identified_js[0:-1]
identified_aas = identified_aas[0:-1]
identified_acs = identified_acs[0:-1]

# %%
len(identified_js),len(identified_aas),len(identified_acs)

j0_fit = np.average(identified_js)
aa_fit = np.average(identified_aas)
ac_fit = np.average(identified_acs)

j0_fit, aa_fit, ac_fit
# Out:
# (52.721561049899194, 0.08165720383533379, 0.04851989436907094)

# %%
# paramys = [0.05151305, 0.37046147, 0.37045137]
# paramys =j0_fit, aa_fit, ac_fit
# paramys = [5.27220332e+01, 8.16570098e-02, 4.85197831e-02]
# paramys = [0.0113262,  0.17690932, 0.89324913]
# paramys = [-.01,.4,.5]
print(j0_fit, aa_fit, ac_fit)
j_fits = BV(np.array(use_v),*paramys)/1000
# plt.plot(np.array(use_v)-0.544,np.zeros_like(use_v),'k',alpha=0.3)
# plt.vlines(0,-4.2,4.2, alpha=0.3)
plt.plot(np.array(use_v),use_current_densities/1000, '--',label='Experimental Data')
plt.plot(np.array(use_v),j_fits,label='Model')
plt.ylabel('Current Density [A/m^2]')
plt.xlabel('Cell Potential [V]')
plt.legend()
plt.savefig('model_vs_data.png',dpi=1000)

# fig, ax1 = plt.subplots()

# color = 'tab:red'
# ax1.set_xlabel('voltage')
# ax1.set_ylabel('data I', color=color)
# ax1.plot(use_v,use_current_densities, '--',color=color)
# # ax1.plot(times,Power_demands, '*',color='tab:grey',label = 'Power Demand (kW)')
# ax1.tick_params(axis='y', labelcolor=color)
# # plt.legend(loc = 'upper center')

# ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

# color = 'tab:blue'
# ax2.set_ylabel('model I', color=color)  # we already handled the x-label with ax1
# ax2.plot(use_v, j_fits, '-',color=color)
# ax2.tick_params(axis='y', labelcolor=color)

# fig.tight_layout()  # otherwise the right y-label is slightly clipped

# plt.show()
# Out:
# 52.721561049899194 0.08165720383533379 0.04851989436907094

# %%
options = np.zeros(len(p0s))
identified_js = []
identified_aas = []
identified_acs = []
for m in range(len(p0s)):
    anss = curve_fit(BV,use_v,use_current_densities,p0s[m],maxfev=2000)
    gs = anss[0] 
#         if gs[1]>0 and gs[2]>0 and gs[1]-p0s[m,1]>1e-3 and gs[2]-p0s[m,2]>1e-3 and gs[0]>1e-2 and gs[0]-p0s[m,0]>1e-2: 
#             print('guess:',p0s[m],'\ngenerated:',anss[0],'\nerrors:',np.sqrt(np.diag(ans[1])),'\n')
    if gs[1]>0 and gs[2]>0 and abs(gs[1]-p0s[m,1])>1e-3 and abs(gs[2]-p0s[m,2])>1e-3 and gs[0]>1e-2 and abs(gs[0]-p0s[m,0])>1e-2: 
        print('guess:',p0s[m],'\ngenerated:',anss[0],'\nerrors:',np.sqrt(np.diag(ans[1])),'\n')
        identified_js.append(gs[0])
        identified_aas.append(gs[1])
        print(gs[1])
        identified_acs.append(gs[2])
        print(gs[2])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-300-09c272196148> in <module>
#       4 identified_acs = []
#       5 for m in range(len(p0s)):
# ----> 6     anss = curve_fit(BV,use_v,use_current_densities,[.2,.4,.6],maxfev=2000)
#       7     gs = anss[0]
#       8 #         if gs[1]>0 and gs[2]>0 and gs[1]-p0s[m,1]>1e-3 and gs[2]-p0s[m,2]>1e-3 and gs[0]>1e-2 and gs[0]-p0s[m,0]>1e-2:
#
# ~\Anaconda3\lib\site-packages\scipy\optimize\minpack.py in curve_fit(f, xdata, ydata, p0, sigma, absolute_sigma, check_finite, bounds, method, jac, **kwargs)
#     750         # Remove full_output from kwargs, otherwise we're passing it in twice.
#     751         return_full = kwargs.pop('full_output', False)
# --> 752         res = leastsq(func, p0, Dfun=jac, full_output=1, **kwargs)
#     753         popt, pcov, infodict, errmsg, ier = res
#     754         cost = np.sum(infodict['fvec'] ** 2)
#
# ~\Anaconda3\lib\site-packages\scipy\optimize\minpack.py in leastsq(func, x0, args, Dfun, full_output, col_deriv, ftol, xtol, gtol, maxfev, epsfcn, factor, diag)
#     394             maxfev = 200*(n + 1)
#     395         retval = _minpack._lmdif(func, x0, args, full_output, ftol, xtol,
# --> 396                                  gtol, maxfev, epsfcn, factor, diag)
#     397     else:
#     398         if col_deriv:
#
# ~\Anaconda3\lib\site-packages\scipy\optimize\minpack.py in func_wrapped(params)
#     456     if transform is None:
#     457         def func_wrapped(params):
# --> 458             return func(xdata, *params) - ydata
#     459     elif transform.ndim == 1:
#     460         def func_wrapped(params):
#
# <ipython-input-287-87abf642585e> in BV(E_cell, j0, aa, ac)
#      13     z = 2
#      14
# ---> 15     j = j0*(np.exp(aa*z*F*overpotential*(R*T)**(-1))-np.exp(ac*z*F*overpotential*(R*T)**(-1)))
#      16
#      17     return j
#
# KeyboardInterrupt:

# %%
[.2,.4,.6]

# %%
curve_fit?

# %%
print(identified_js)
print('\n',identified_aas)
print('\n',identified_acs)

print(np.std(identified_aas)/np.average(identified_aas), np.std(identified_acs)/np.average(identified_acs), np.std(identified_js)/np.average(identified_js))

np.array(identified_aas) - np.array(identified_acs)
# Out:
# [0.01125041678483074, 0.013498123338869421, 0.015431431373571697, 0.012183451938166438, 0.010206038558991477, 0.01189673387930526, 0.014711681575618208, 0.01381243236564588]
#
#  [0.38387822482182843, 0.3838658841599409, 0.38387935266670536, 0.38383905570964977, 0.38390035473828626, 0.38388806456429353, 0.38391374460281363, 0.38387832342293465]
#
#  [0.38387822482182843, 0.3838658841599409, 0.38387935266670536, 0.38383905570964977, 0.38390035473828626, 0.38388806456429353, 0.38391374460281363, 0.38387832342293465]
# 5.447920694756275e-05 5.447920694756275e-05 0.12990239161552328
# array([0., 0., 0., 0., 0., 0., 0., 0.])

# %%
j_fits = BV(np.array(E_cycle1[0:a]),j0_fit, aa_fit, ac_fit)
plt.plot(E_cycle1[0:a],i_cycle1[0:a], '--')
plt.plot(E_cycle1[0:a],j_fits)

# %%
a = int(len(E_cycle1)/2)
b = int(len(E_cycle2)/2)
c = int(len(E_cycle3)/2)
d = int(len(E_cycle4)/2)

plt.plot(E_cycle1[0:a],i_cycle1[0:a],label = 'Cycle1')
plt.plot(E_cycle2[0:b],i_cycle2[0:b],label = 'Cycle2')
plt.plot(E_cycle3[0:c],i_cycle3[0:c],label = 'Cycle3')
plt.plot(E_cycle4[0:d],i_cycle4[0:d],label = 'Cycle4')
plt.title('cycle up')
plt.xlabel('Voltage (V)')
plt.ylabel('Current (mA)')
plt.legend()
plt.show()

plt.plot(E_cycle1[a:],i_cycle1[a:],label = 'Cycle1')
plt.plot(E_cycle2[b:],i_cycle2[b:],label = 'Cycle2')
plt.plot(E_cycle3[c:],i_cycle3[c:],label = 'Cycle3')
plt.plot(E_cycle4[d:],i_cycle4[d:],label = 'Cycle4')
plt.title('cycle down')
plt.xlabel('Voltage (V)')
plt.ylabel('Current (mA)')
plt.legend()
plt.show()

# %%
j0s = []
aas = []
acs = []

ans_up = curve_fit(BV, np.array(E_cycle1[0:a]),i_cycle1[0:a])
ans_down = curve_fit(BV, np.array(E_cycle1[a:]),i_cycle1[a:])

j0_fit_up, aa_fit_up, ac_fit_up = ans_up[0]
print('UP: j0,aa,ac:', j0_fit_up, aa_fit_up, ac_fit_up)
pcov = ans_up[1]
perr = np.sqrt(np.diag(pcov))
print('errors:',perr)
print('errors r this % of values:',perr/ans_up[0]*100 )
print('')

j0s.append(j0_fit_up)
aas.append(aa_fit_up)
acs.append(ac_fit_up)

j0_fit_down, aa_fit_down, ac_fit_down = ans_down[0]
print('DOWN: j0,aa,ac:', j0_fit_down, aa_fit_down, ac_fit_down)
pcov2 = ans_down[1]
perr2 = np.sqrt(np.diag(pcov2))
print('errors:',perr2)
print('errors r this % of values:',perr2/ans_down[0]*100 )
# Out:
# UP: j0,aa,ac: 0.6984020846041802 0.06535228115004106 0.36501861371928523
# errors: [0.00586936 0.00034955 0.01025805]
# errors r this % of values: [0.84039804 0.53486944 2.81028169]
#
# DOWN: j0,aa,ac: 1.119410784859951 0.1472909871246844 257.9540604125512
# errors: [inf inf inf]
# errors r this % of values: [inf inf inf]
# C:\Users\MaryLou\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)

# %%
ans_up = curve_fit(BV, np.array(E_cycle2[0:b]),i_cycle2[0:b])
ans_down = curve_fit(BV, np.array(E_cycle2[b:]),i_cycle2[b:])

j0_fit_up, aa_fit_up, ac_fit_up = ans_up[0]
print('UP: j0,aa,ac:', j0_fit_up, aa_fit_up, ac_fit_up)
pcov = ans_up[1]
perr = np.sqrt(np.diag(pcov))
print('errors:',perr)
print('errors r this % of values:',perr/ans_up[0]*100 )
print('')

j0s.append(j0_fit_up)
aas.append(aa_fit_up)
acs.append(ac_fit_up)

j0_fit_down, aa_fit_down, ac_fit_down = ans_down[0]
print('DOWN: j0,aa,ac:', j0_fit_down, aa_fit_down, ac_fit_down)
pcov2 = ans_down[1]
perr2 = np.sqrt(np.diag(pcov2))
print('errors:',perr2)
print('errors r this % of values:',perr2/ans_down[0]*100 )
# Out:
# UP: j0,aa,ac: 0.7127588310239279 0.06258918315744932 0.34896900119878377
# errors: [0.00241114 0.00013557 0.00380841]
# errors r this % of values: [0.33828246 0.21660146 1.09133246]
#
# DOWN: j0,aa,ac: 1.1921914833840281 0.14955406290416606 116.5814530217532
# errors: [inf inf inf]
# errors r this % of values: [inf inf inf]

# %%
ans_up = curve_fit(BV, np.array(E_cycle3[0:c]),i_cycle3[0:c])
ans_down = curve_fit(BV, np.array(E_cycle3[c:]),i_cycle3[c:])

j0_fit_up, aa_fit_up, ac_fit_up = ans_up[0]
print('UP: j0,aa,ac:', j0_fit_up, aa_fit_up, ac_fit_up)
pcov = ans_up[1]
perr = np.sqrt(np.diag(pcov))
print('errors:',perr)
print('errors r this % of values:',perr/ans_up[0]*100 )
print('')

j0s.append(j0_fit_up)
aas.append(aa_fit_up)
acs.append(ac_fit_up)

j0_fit_down, aa_fit_down, ac_fit_down = ans_down[0]
print('DOWN: j0,aa,ac:', j0_fit_down, aa_fit_down, ac_fit_down)
pcov2 = ans_down[1]
perr2 = np.sqrt(np.diag(pcov2))
print('errors:',perr2)
print('errors r this % of values:',perr2/ans_down[0]*100 )
# Out:
# C:\Users\MaryLou\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: overflow encountered in multiply
# UP: j0,aa,ac: 0.7356959942030771 0.06207330927141335 0.32734228226595424
# errors: [0.00274808 0.00014523 0.00345089]
# errors r this % of values: [0.37353467 0.23397034 1.05421591]
#
# DOWN: j0,aa,ac: 1.2460455932845593 0.1515682751999209 115.0372045957835
# errors: [inf inf inf]
# errors r this % of values: [inf inf inf]

# %%
ans_up = curve_fit(BV, np.array(E_cycle4[0:d]),i_cycle4[0:d])
ans_down = curve_fit(BV, np.array(E_cycle4[d:]),i_cycle4[d:])

j0_fit_up, aa_fit_up, ac_fit_up = ans_up[0]
print('UP: j0,aa,ac:', j0_fit_up, aa_fit_up, ac_fit_up)
pcov = ans_up[1]
perr = np.sqrt(np.diag(pcov))
print('errors:',perr)
print('errors r this % of values:',perr/ans_up[0]*100 )
print('')

j0s.append(j0_fit_up)
aas.append(aa_fit_up)
acs.append(ac_fit_up)

j0_fit_down, aa_fit_down, ac_fit_down = ans_down[0]
print('DOWN: j0,aa,ac:', j0_fit_down, aa_fit_down, ac_fit_down)
pcov2 = ans_down[1]
perr2 = np.sqrt(np.diag(pcov2))
print('errors:',perr2)
print('errors r this % of values:',perr2/ans_down[0]*100 )
# Out:
# UP: j0,aa,ac: 0.7424016195274946 0.06161643722626101 0.32596896840055534
# errors: [0.00289069 0.00015094 0.0035561 ]
# errors r this % of values: [0.3893702  0.24496552 1.09093141]
#
# DOWN: j0,aa,ac: 1.2466608628556233 0.1511128461184393 147.4240335298961
# errors: [inf inf inf]
# errors r this % of values: [inf inf inf]
# C:\Users\MaryLou\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in subtract

# %%
print(j0s)
np.average(np.array(j0s)), np.std(np.array(j0s)), np.std(np.array(j0s))/np.average(np.array(j0s))
# Out:
# [0.6984020846041802, 0.7127588310239279, 0.7356959942030771, 0.7424016195274946]
# (0.72231463233967, 0.017647033586351654, 0.02443122816049101)

# %%
print(aas)
np.average(np.array(aas)), np.std(np.array(aas)),np.std(np.array(aas))/np.average(np.array(aas))
# Out:
# [0.06535228115004106, 0.06258918315744932, 0.06207330927141335, 0.06161643722626101]
# (0.06290780270129119, 0.001452669729732964, 0.023092043710869394)

# %%
print(acs)
np.average(np.array(acs)), np.std(np.array(acs)),np.std(np.array(acs))/np.average(np.array(acs))
# Out:
# [0.36501861371928523, 0.34896900119878377, 0.32734228226595424, 0.32596896840055534]
# (0.34182471639614465, 0.01620295745545043, 0.04740136297421113)

# %%
P_2500 = np.array(rpm2500['P/W'])
Ewe_2500 = np.array(rpm2500['Ewe/V'])
I_2500 = P_2500/Ewe_2500*1000 
cycles_2500 = rpm2500['cycle number']

plt.plot(Ewe_2500,I_2500)
plt.title('2500 rpm')
plt.show()
plt.plot(Ewe_100,I_100)
plt.title('100 rpm')
# Out:
# Text(0.5, 1.0, '100 rpm')

# %%
def find_params(n):
    RPM = rpm100,rpm400,rpm900,rpm1600,rpm2500
#     if rpm==100: n=0
#     elif rpm==400: n=1
#     elif rpm==900: n=2
#     elif rpm==1600: n=3
#     elif rpm==2500: n=4
    data = RPM[n]
    
    Ps = np.array(data['P/W'])
    Es = np.array(data['Ewe/V'])
    Is = Ps/Es*1000 
    cycle_nums = data['cycle number']
    
    E_cycle1 = []
    E_cycle2 = []
    E_cycle3 = []
    E_cycle4 = []

    i_cycle1 = []
    i_cycle2 = []
    i_cycle3 = []
    i_cycle4 = []

    for m in range(len(cycle_nums)):
        if cycle_nums[m] == 1:
            E_cycle1.append(Es[m])
            i_cycle1.append(Is[m])
        elif cycle_nums[m] == 2:
            E_cycle2.append(Es[m])
            i_cycle2.append(Is[m])
        elif cycle_nums[m] == 3:
            E_cycle3.append(Es[m])
            i_cycle3.append(Is[m])
        elif cycle_nums[m] == 4:
            E_cycle4.append(Es[m])
            i_cycle4.append(Is[m])
            
    E_sorted = E_cycle1, E_cycle2, E_cycle3, E_cycle4
    i_sorted = i_cycle1, i_cycle2, i_cycle3, i_cycle4
            
    a = int(len(E_cycle1)/2)
    b = int(len(E_cycle2)/2)
    c = int(len(E_cycle3)/2)
    d = int(len(E_cycle4)/2)
    halfways = a,b,c,d
    
    j0s = []
    aas = []
    acs = []
    
    for cycle in range(4):
        halfway = halfways[cycle]
        E = E_sorted[cycle]
        i = i_sorted[cycle]
        
        ans = curve_fit(BV, np.array(E[0:halfway]),i[0:halfway]) #first half of cycle

        j0_fit, aa_fit, ac_fit = ans[0]
        print('Cycle {}:\nj0: {:.2f} aa: {:.2f} ac: {:.2f}'.format(cycle+1,j0_fit, aa_fit, ac_fit))
        pcov = ans[1]
        perr = np.sqrt(np.diag(pcov))
        print('errors:',perr)
        print('errors are this fraction of values:',perr/ans[0])
        print('')

        j0s.append(j0_fit)
        aas.append(aa_fit)
        acs.append(ac_fit)
        plt.plot()
        
    avg_params = np.average(np.array(j0s)), np.average(np.array(aas)), np.average(np.array(acs))
    print(avg_params)
    solution_object = avg_params
    print('print average values and errors here')
    return solution_object

# one_hundo = find_params(100)
# twentyfive_hundo = find_params(2500)
# one_hundo,twentyfive_hundo

# %%
params = []
for n in range(len(RPM)):
    param = find_params(n)
    params.append(param)

params
# Out:
# C:\Users\MaryLou\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: RuntimeWarning: invalid value encountered in subtract
#   if sys.path[0] == '':
# Cycle 1:
# j0: 12.44 aa: 0.28 ac: 0.28
# errors: [6.71230088e+07 1.39152226e+02 1.39196290e+02]
# errors are this fraction of values: [5.39562914e+06 4.99090012e+02 4.99338024e+02]
#
# Cycle 2:
# j0: 4112.97 aa: 0.89 ac: 0.89
# errors: [4.57829393e+09 5.91782463e-03 6.49549184e-03]
# errors are this fraction of values: [1.11313559e+06 6.66568257e-03 7.31635179e-03]
#
# Cycle 3:
# j0: 0.00 aa: -0.06 ac: -0.06
# errors: [30.87573235 13.12216509 12.970184  ]
# errors are this fraction of values: [223299.44348525   -232.52830713   -229.36669279]
#
# Cycle 4:
# j0: 12936.44 aa: 0.28 ac: 0.28
# errors: [7.61346399e+10 1.36184780e-01 1.60891499e-01]
# errors are this fraction of values: [5.88528411e+06 4.86588392e-01 5.74865631e-01]
#
# (4265.4633834779615, 0.3475152092707207, 0.34747382231475654)
# print average values and errors here
# Cycle 1:
# j0: 1783.14 aa: 0.92 ac: 0.92
# errors: [5.10182243e+09            nan            nan]
# errors are this fraction of values: [2861143.35170143              nan              nan]
#
# Cycle 2:
# j0: 0.00 aa: -0.05 ac: -0.05
# errors: [1.08662468 1.82438947 1.75382226]
# errors are this fraction of values: [9041.87866122  -33.85476961  -32.30998956]
#
# Cycle 3:
# j0: 0.00 aa: -0.05 ac: -0.05
# errors: [0.66079085 1.54446569 1.47398443]
# errors are this fraction of values: [6437.93672545  -28.71220804  -27.16732987]
# C:\Users\MaryLou\Anaconda3\lib\site-packages\ipykernel_launcher.py:62: RuntimeWarning: invalid value encountered in sqrt
# Cycle 4:
# j0: 19526.27 aa: 0.28 ac: 0.28
# errors: [1.75767908e+11 1.22987866e-01 1.82784138e-01]
# errors are this fraction of values: [9.00161434e+06 4.39750096e-01 6.53555134e-01]
#
# (5327.351614457234, 0.2739934318094964, 0.27377918988296185)
# print average values and errors here
# Cycle 1:
# j0: 2009.79 aa: 0.92 ac: 0.92
# errors: [3.41934909e+09            nan            nan]
# errors are this fraction of values: [1701348.61337934              nan              nan]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-25-fe8bd2fbe5e8> in <module>
#       1 params = []
#       2 for n in range(len(RPM)):
# ----> 3     param = find_params(n)
#       4     params.append(param)
#       5
#
# <ipython-input-24-ecf47244d243> in find_params(n)
#      55         i = i_sorted[cycle]
#      56
# ---> 57         ans = curve_fit(BV, np.array(E[0:halfway]),i[0:halfway]) #first half of cycle
#      58
#      59         j0_fit, aa_fit, ac_fit = ans[0]
#
# ~\Anaconda3\lib\site-packages\scipy\optimize\minpack.py in curve_fit(f, xdata, ydata, p0, sigma, absolute_sigma, check_finite, bounds, method, jac, **kwargs)
#     754         cost = np.sum(infodict['fvec'] ** 2)
#     755         if ier not in [1, 2, 3, 4]:
# --> 756             raise RuntimeError("Optimal parameters not found: " + errmsg)
#     757     else:
#     758         # Rename maxfev (leastsq) to max_nfev (least_squares), if specified.
#
# RuntimeError: Optimal parameters not found: Number of calls to function has reached maxfev = 800.

# %%
# plt.plot(E_cycle1,i_cycle1,label = 'Cycle1')
plt.plot(E_cycle2,i_cycle2,label = 'Cycle2')
plt.plot(E_cycle3,i_cycle3,label = 'Cycle3')
plt.plot(E_cycle4,i_cycle4,label = 'Cycle4')
plt.title('Plot parameterized by $j_0$, $a_a$, and $a_c$')
plt.xlabel('Voltage (V)')
plt.ylabel('Current (mA)')
plt.legend()
plt.savefig('V_I_graph.png', dpi=1000, format = 'png',transparent=True)
plt.show()
